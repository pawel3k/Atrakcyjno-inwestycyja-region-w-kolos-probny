# %%
# !pip uninstall openpyxl
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np

# %%
zbior_danych = pd.read_excel("zbior_danych_2.xlsx")
zbior_danych ### definijuemy zbiór danych
# Out:
#      plec  wiek  KLASA_MIEJSCOWOSCI  WOJEWODZTWO  ...  fp65  fp66  fp70  fp106
# 0       1    48                   1            2  ...  2000  3000     5      5
# 1       1    55                   1            2  ...  1900  3000     6      5
# 2       1    22                   1            2  ...  1100  2000     2      6
# 3       1    36                   1            2  ...  3000  6000     4      5
# 4       1    34                   1            2  ...  1200  6000     1      6
# ..    ...   ...                 ...          ...  ...   ...   ...   ...    ...
# 805     2    42                   6           32  ...  1200  3000     4      8
# 806     2    31                   6           32  ...  3000  3200     4      7
# 807     2    39                   6           32  ...  1300  2000     6      7
# 808     2    52                   6           32  ...  1100  1100     5      7
# 809     2    28                   6           32  ...  1500  1500     2      8
#
# [810 rows x 43 columns]

# %%
### ZAD 1

osobyRozwiedzione = np.sum(zbior_danych.fC11 == 4)
osobyRozwiedzione
# Out:
# 26

# %% [markdown]
# Liczba osób rozwiedzionych = 26

# %%
### ZAD 2

rozwiedzioneWiek = zbior_danych[(zbior_danych.fC11 == 4) & (zbior_danych.wiek >= 0)] 
rozwiedzioneWiek
# Out:
#      plec  wiek  KLASA_MIEJSCOWOSCI  WOJEWODZTWO  ...  fp65  fp66  fp70  fp106
# 0       1    48                   1            2  ...  2000  3000     5      5
# 7       1    54                   4            2  ...  7500  9000     3      1
# 30      2    53                   1            2  ...  3500  5000     5      4
# 32      2    36                   1            2  ...  4600  5600     3      7
# 58      1    45                   2            4  ...  1000  1000     6      8
# 66      1    45                   4            4  ...  1200  2000     6      5
# 87      2    61                   2            4  ...  3000  3000     2      1
# 122     1    52                   6            6  ...  2000  2000     4      8
# 144     2    36                   4            6  ...  1495  1700     3      5
# 154     2    58                   6            6  ...  1500  1700     4      7
# 164     1    44                   3            8  ...  3000  4200     4      7
# 236     2    63                   1           10  ...  4000  4000     3      5
# 286     2    35                   1           12  ...  3000  1200     4      5
# 298     2    36                   6           12  ...  1200  1400     3      3
# 313     1    59                   1           14  ...  2500  3000     4      1
# 364     2    52                   1           14  ...  1500  2000     3      7
# 373     2    55                   2           14  ...  2100  2200     3      7
# 427     2    42                   3           16  ...  3000  3500     4      3
# 531     1    35                   6           22  ...  5200  5200     3      6
# 554     2    39                   2           22  ...  2200  3200     6      3
# 610     1    42                   6           24  ...  2000  3000     2      8
# 651     2    37                   6           24  ...  4000  5000     2      5
# 698     2    50                   5           28  ...  4000  5000     6      5
# 718     1    52                   4           30  ...  5000  5000     3      5
# 805     2    42                   6           32  ...  1200  3000     4      8
# 807     2    39                   6           32  ...  1300  2000     6      7
#
# [26 rows x 43 columns]

# %%
np.mean(rozwiedzioneWiek)
# Out:
# plec                     1.615385
# wiek                    46.538462
# KLASA_MIEJSCOWOSCI       3.461538
# WOJEWODZTWO             13.538462
# eduk4_2011               3.192308
# lata_nauki_2011         14.692308
# fC4                      1.384615
# fC11                     4.000000
# fC37                    12.961538
# fD4                     41.346154
# fp3                      2.653846
# fp29                     1.615385
# fp40                     6.653846
# fp41                     8.807692
# fp55                   169.730769
# fp56                    74.500000
# fp58_1                   4.961538
# fp58_2                   2.115385
# fp58_3                   3.500000
# fp58_4                   4.461538
# fp58_5                   5.230769
# fp58_6                   5.692308
# fp58_7                   4.076923
# fp58_8                   2.730769
# fp58_9                   4.730769
# fp58_10                  3.076923
# fp58_11                  2.346154
# fp58_12                  4.038462
# fp58_13                  4.615385
# fp58_14                  3.884615
# fp58_15                  2.153846
# fp58_16                  2.307692
# fp58_17                  4.500000
# fp58_18                  2.423077
# fp58_19                  2.961538
# fp58_20                  3.692308
# fp58_21                  3.500000
# fp58_22                  5.384615
# fp58_23                  2.230769
# fp65                  2807.500000
# fp66                  3342.307692
# fp70                     3.884615
# fp106                    5.230769
# dtype: float64

# %% [markdown]
# Średni wiek tych osób to: 46.538462

# %%
### ZAD 3

sumaWielkopolska = np.sum((zbior_danych.plec == 1) & (zbior_danych.WOJEWODZTWO == 30)) ### Łączna ilosć osób z wlkp o podanych wartosciach
sumaPodlasie = np.sum((zbior_danych.plec == 2) & (zbior_danych.WOJEWODZTWO == 20)) ### Łączna ilosć osób z podlasia o podanych wartosciach

sumaKoncowa = sumaWielkopolska + sumaPodlasie
sumaKoncowa
# Out:
# 54

# %% [markdown]
# Udział w badaniu ankietowym wzięło łącznie: 54 osoby

# %%
### ZAD 4

kod_2 = np.sum((zbior_danych.plec == 2) & (zbior_danych.WOJEWODZTWO == 2) & (zbior_danych.KLASA_MIEJSCOWOSCI == 6))
kod_12 = np.sum((zbior_danych.plec == 2) & (zbior_danych.WOJEWODZTWO == 12) & (zbior_danych.KLASA_MIEJSCOWOSCI == 6))
kod_22 = np.sum((zbior_danych.plec == 2) & (zbior_danych.WOJEWODZTWO == 22) & (zbior_danych.KLASA_MIEJSCOWOSCI == 6))
kod_32 = np.sum((zbior_danych.plec == 2) & (zbior_danych.WOJEWODZTWO == 32) & (zbior_danych.KLASA_MIEJSCOWOSCI == 6))

sumaKody = kod_2 + kod_12 + kod_22 + kod_32
sumaKody
# Out:
# 46

# %% [markdown]
# Suma tych osób to : 46

# %%
### ZAD 5

### Pierwsza kolumna

kawalerP = np.sum((zbior_danych.fC11 == 1) & (zbior_danych.fp29 == 1)) 
zonatyP = np.sum((zbior_danych.fC11 == 2) & (zbior_danych.fp29 == 1)) 
wdowiecP = np.sum((zbior_danych.fC11 == 3) & (zbior_danych.fp29 == 1))
rozwiedzionyP = np.sum((zbior_danych.fC11 == 4) & (zbior_danych.fp29 == 1))
prawnaP = np.sum((zbior_danych.fC11 == 5) & (zbior_danych.fp29 == 1))
faktycznaP = np.sum((zbior_danych.fC11 == 6) & (zbior_danych.fp29 == 1))

kawalerP, zonatyP, wdowiecP, rozwiedzionyP, prawnaP, faktycznaP
# Out:
# (106, 240, 5, 10, 2, 1)

# %% [markdown]
# Wartości dla pierwszej kolumny: (106, 240, 5, 10, 2, 1)

# %%
### Druga kolumna

kawalerO = np.sum((zbior_danych.fC11 == 1) & (zbior_danych.fp29 == 2))
zonatyO = np.sum((zbior_danych.fC11 == 2) & (zbior_danych.fp29 == 2))
wdowiecO = np.sum((zbior_danych.fC11 == 3) & (zbior_danych.fp29 == 2))
rozwiedzionyO = np.sum((zbior_danych.fC11 == 4) & (zbior_danych.fp29 == 2))
prawnaO = np.sum((zbior_danych.fC11 == 5) & (zbior_danych.fp29 == 2))
faktycznaO = np.sum((zbior_danych.fC11 == 6) & (zbior_danych.fp29 == 2))

kawalerO, zonatyO, wdowiecO, rozwiedzionyO, prawnaO, faktycznaO
# Out:
# (87, 326, 14, 16, 0, 3)

# %% [markdown]
# Wartości dla drugiej kolumny: (87, 326, 14, 16, 0, 3)

# %%
pd.crosstab(zbior_danych.fC11, zbior_danych.fp29)
# Out:
# fp29    1    2
# fC11
# 1     106   87
# 2     240  326
# 3       5   14
# 4      10   16
# 5       2    0
# 6       1    3

# %%
### ZAD 6

import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = zbior_danych.query("fp65 >= 0 & fp65 <= 27000 &fp55 >= 150 & fp55 <= 198 & wiek >= 18 & wiek <= 74")

modelRegresji = smf.ols(formula = "fp65 ~ (fp55 + wiek)", data = data).fit() ### Model regresji liniowej
print(modelRegresji.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   fp65   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     19.16
# Date:                Wed, 02 Feb 2022   Prob (F-statistic):           7.41e-09
# Time:                        16:13:34   Log-Likelihood:                -7135.5
# No. Observations:                 810   AIC:                         1.428e+04
# Df Residuals:                     807   BIC:                         1.429e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4691.3178   1156.293     -4.057      0.000   -6961.014   -2421.622
# fp55          34.4078      6.459      5.327      0.000      21.729      47.086
# wiek          19.6958      4.979      3.956      0.000       9.922      29.470
# ==============================================================================
# Omnibus:                     1008.825   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           178641.120
# Skew:                           6.144   Prob(JB):                         0.00
# Kurtosis:                      74.708   Cond. No.                     3.57e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Adj. R-squared:                  0.043
#
#                  coef
#
# ------------------------------------------------------------------------------
# Intercept  -4691.3178
# fp55          34.4078
# wiek          19.6958

# %%
### ZAD 7

kawaler = np.sum(zbior_danych.fC11 == 1)
zonaty = np.sum(zbior_danych.fC11 == 2)
wdowiec = np.sum(zbior_danych.fC11 == 3)
rozwiedziony = np.sum(zbior_danych.fC11 == 4)
separacjaP= np.sum(zbior_danych.fC11 == 5)
separacjaF = np.sum(zbior_danych.fC11 == 6)

suma = zbior_danych.value_counts("fC11")
suma
# Out:
# fC11
# 2    566
# 1    193
# 4     26
# 3     19
# 6      4
# 5      2
# dtype: int64

# %%
sumaOgolna = np.sum(suma)
sumaOgolna
# Out:
# 810

# %%
kawalerOdsetek = kawaler / sumaOgolna
zonatyOdsetek = zonaty / sumaOgolna
wdowiecOdsetek = wdowiec / sumaOgolna
rozwiedzionyOdsetek = rozwiedziony / sumaOgolna
separacjaP_Odsetek = separacjaP / sumaOgolna
separacjaF_Odsetek = separacjaF / sumaOgolna

kawalerOdsetek, zonatyOdsetek, wdowiecOdsetek, rozwiedzionyOdsetek, separacjaP_Odsetek, separacjaF_Odsetek
# Out:
# (0.2382716049382716,
#  0.6987654320987654,
#  0.02345679012345679,
#  0.03209876543209877,
#  0.0024691358024691358,
#  0.0049382716049382715)

# %% [markdown]
# Pierwszy słupek = 23%
#
# Drugi słupek = 69%
#
# Trzeci słupek = 2,3%
#
# Czwarty słupek = 3.2%
#
# Piąty słupek = 0,24%
#
# Szósty słupek = 0,49%
#
# Dla poniższego wkresu

# %%
zbior_danych.fC11.hist()

# %%
### ZAD 8

dane = zbior_danych[(zbior_danych.wiek >= 0) & (zbior_danych.fp56) & (zbior_danych.plec == 2) & (zbior_danych.KLASA_MIEJSCOWOSCI == 6)] [["wiek", "fp56", "plec", "KLASA_MIEJSCOWOSCI"]]

korelacjaPearsona = dane.corr(method="pearson")
korelacjaPearsona ### INTERPRETACJA ?????
# Out:
#                         wiek      fp56  plec  KLASA_MIEJSCOWOSCI
# wiek                1.000000  0.478465   NaN                 NaN
# fp56                0.478465  1.000000   NaN                 NaN
# plec                     NaN       NaN   NaN                 NaN
# KLASA_MIEJSCOWOSCI       NaN       NaN   NaN                 NaN

# %%
### ZAD 9

kwartyl = zbior_danych[(zbior_danych.fp56) & (zbior_danych.plec == 1) & (zbior_danych.WOJEWODZTWO == 30)]  [["plec", "WOJEWODZTWO", "fp56"]]

k1 = np.quantile(kwartyl, 0.25) ### kwartyl pierwszy
k2 = np.quantile(kwartyl, 0.5)  ### kwartyl drugi (mediana)
k3 = np.quantile(kwartyl, 0.75) ### kwartyl trzeci

k1, k2, k3
# Out:
# (1.0, 30.0, 81.5)

# %% [markdown]
# Q1 = 1.0
#
# Q2 = 30.0
#
# Q3 = 81.5

# %%
### ZAD 10

def funkcjaTabela(plec, fC11):
  tabela = pd.crosstab(zbior_danych.plec, zbior_danych.fC11)
  return tabela

# %%
funkcjaTabela(plec, fC11) ### chyba jest ok
# Out:
# fC11    1    2   3   4  5  6
# plec
# 1     112  312   2  10  1  3
# 2      81  254  17  16  1  1

# %%
### ZAD 11

import math

# %%
a = 3
pole = (a**2 * (math.sqrt(3)))/4
obwod = a*3
print("Pole trójkata wynosi:")
print(pole)
print("Obwód trójkata wynosi:")
print(obwod)
# Out:
# Pole trójkata wynosi:
# 3.8971143170299736
# Obwód trójkata wynosi:
# 9
